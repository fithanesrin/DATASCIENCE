# %% [markdown]
# <a href="https://colab.research.google.com/github/fithanesrin/DATASCIENCE/blob/main/dataframe_(pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#create a dataframe
import pandas as pd
import numpy as np
data = {
    "name":["alice","bob","charlie","david","emma"],
    "age":[20,21,19,22,20],
    "marks":[85,72,np.nan,90,65],
    "attendance":[95,80,75,np.nan,88],
    "city":["kochi","delhi","mumbai","kochi","chennai"]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       name  age  marks  attendance     city
# 0    alice   20   85.0        95.0    kochi
# 1      bob   21   72.0        80.0    delhi
# 2  charlie   19    NaN        75.0   mumbai
# 3    david   22   90.0         NaN    kochi
# 4     emma   20   65.0        88.0  chennai

# %%
# first 3 rows print cheyan df.head()
#last rows print cheyan df.tail()
print("\n fist 3 rows:")
print(df.head(3))


print("\n last 2 rows:")
print(df.tail(2))
# Out:
#  fist 3 rows:
#       name  age  marks  attendance    city
# 0    alice   20   85.0        95.0   kochi
# 1      bob   21   72.0        80.0   delhi
# 2  charlie   19    NaN        75.0  mumbai
#
#  last 2 rows:
#     name  age  marks  attendance     city
# 3  david   22   90.0         NaN    kochi
# 4   emma   20   65.0        88.0  chennai

# %%
#shape- datas arrange cheyan
print(df.shape)
print(df.columns)
print(df.dtypes)
print(df["marks"])    # only marks
print(df[["name" ,"marks"]])   #marks and name
print("\t\t\t----------------------------------------------------\t\t\t")
# Out:
# (5, 5)
# Index(['name', 'age', 'marks', 'attendance', 'city'], dtype='object')
# name           object
# age             int64
# marks         float64
# attendance    float64
# city           object
# dtype: object
# 0    85.0
# 1    72.0
# 2     NaN
# 3    90.0
# 4    65.0
# Name: marks, dtype: float64
#       name  marks
# 0    alice   85.0
# 1      bob   72.0
# 2  charlie    NaN
# 3    david   90.0
# 4     emma   65.0
# 			----------------------------------------------------

# %%
#slicing
print("\n first 3 roes:")
print(df.iloc[0:3])        #integer base,complete kittulaaa
print("\n rows 1 to 3, name and marks:")
print(df.loc[1:3,["name","marks"]])         #label or position based,complete kittum
# Out:
#  first 3 roes:
#       name  age  marks  attendance    city
# 0    alice   20   85.0        95.0   kochi
# 1      bob   21   72.0        80.0   delhi
# 2  charlie   19    NaN        75.0  mumbai
#
#  rows 1 to 3, name and marks:
#       name  marks
# 1      bob   72.0
# 2  charlie    NaN
# 3    david   90.0

# %%
#filter
print("\n students with marks greater than 75:")
print(df[df["marks"]>75])

print("\n students from kochi:")
print(df[df["city"]=="kochi"])

print("\n students with marks >70 and attendance >80:")
print(df[(df["marks"]>70) & (df["attendance"]>80)])
# Out:
#  students with marks greater than 75:
#     name  age  marks  attendance   city
# 0  alice   20   85.0        95.0  kochi
# 3  david   22   90.0         NaN  kochi
#
#  students from kochi:
#     name  age  marks  attendance   city
# 0  alice   20   85.0        95.0  kochi
# 3  david   22   90.0         NaN  kochi
#
#  students with marks >70 and attendance >80:
#     name  age  marks  attendance   city
# 0  alice   20   85.0        95.0  kochi

# %%
# mathematical operations
print("\nmarks + 5:")
print(df["marks"]+ 5)

print("\nmarks * 2:")
print(df["marks"]*2)

print("\naverage marks:")
print(df["marks"].mean())

print("\nmax marks:")
print(df["marks"].max())

print("\nmin marks:")
print(df["marks"].min())

print("\ntotal marks:")
print(df["marks"].sum())
# Out:
# marks + 5:
# 0    90.0
# 1    77.0
# 2     NaN
# 3    95.0
# 4    70.0
# Name: marks, dtype: float64
#
# marks * 2:
# 0    170.0
# 1    144.0
# 2      NaN
# 3    180.0
# 4    130.0
# Name: marks, dtype: float64
#
# average marks:
# 78.0
#
# max marks:
# 90.0
#
# min marks:
# 65.0
#
# total marks:
# 312.0

# %%
# sorting
print("\nsorted by marks:")
print(df.sort_values("marks"))

print("\nsorted by marks - highest first:")
print(df.sort_values("marks",ascending=False))
# Out:
# sorted by marks:
#       name  age  marks  attendance     city
# 4     emma   20   65.0        88.0  chennai
# 1      bob   21   72.0        80.0    delhi
# 0    alice   20   85.0        95.0    kochi
# 3    david   22   90.0         NaN    kochi
# 2  charlie   19    NaN        75.0   mumbai
#
# sorted by marks - highest first:
#       name  age  marks  attendance     city
# 3    david   22   90.0         NaN    kochi
# 0    alice   20   85.0        95.0    kochi
# 1      bob   21   72.0        80.0    delhi
# 4     emma   20   65.0        88.0  chennai
# 2  charlie   19    NaN        75.0   mumbai

# %%
# RENAMING COLUMNS
df_rename = df.rename(
    columns={
        "marks":"score",
        "attendance":"attendence_percentage"
    }
)
print("\nrenamed DataFrame:")
print(df_rename)
# Out:
# renamed DataFrame:
#       name  age  score  attendence_percentage     city
# 0    alice   20   85.0                   95.0    kochi
# 1      bob   21   72.0                   80.0    delhi
# 2  charlie   19    NaN                   75.0   mumbai
# 3    david   22   90.0                    NaN    kochi
# 4     emma   20   65.0                   88.0  chennai

# %%
df_renamed=df.rename(columns={"marks":"score","attendance":"attendence_percentage"})
print(df_renamed)
# Out:
#       name  age  score  attendence_percentage     city
# 0    alice   20   85.0                   95.0    kochi
# 1      bob   21   72.0                   80.0    delhi
# 2  charlie   19    NaN                   75.0   mumbai
# 3    david   22   90.0                    NaN    kochi
# 4     emma   20   65.0                   88.0  chennai

# %%
#checking missing values
print("\nchecking missing values:")
print(df.isna())

print("\nNumber of missing values:")
print(df.isna().sum())

print(df.dropna())  # null remove
# Out:
# checking missing values:
#     name    age  marks  attendance   city
# 0  False  False  False       False  False
# 1  False  False  False       False  False
# 2  False  False   True       False  False
# 3  False  False  False        True  False
# 4  False  False  False       False  False
#
# Number of missing values:
# name          0
# age           0
# marks         1
# attendance    1
# city          0
# dtype: int64
#     name  age  marks  attendance     city
# 0  alice   20   85.0        95.0    kochi
# 1    bob   21   72.0        80.0    delhi
# 4   emma   20   65.0        88.0  chennai

# %%
#forward fill  - nulll ulla values remove akki mele ullath fill akum
df_forward = df.copy()
df_forward = df_forward.ffill()

print("\nforward fill:")
print(df_forward)
# Out:
# forward fill:
#       name  age  marks  attendance     city
# 0    alice   20   85.0        95.0    kochi
# 1      bob   21   72.0        80.0    delhi
# 2  charlie   19   72.0        75.0   mumbai
# 3    david   22   90.0        75.0    kochi
# 4     emma   20   65.0        88.0  chennai

# %%
#backward fill - null ulla value remove akki adinthe thazhe ullath no kond fill akum
df_backward = df.copy()
df_backward = df_backward.bfill()

print("\nbackward fill:")
print(df_backward)
# Out:
# backward fill:
#       name  age  marks  attendance     city
# 0    alice   20   85.0        95.0    kochi
# 1      bob   21   72.0        80.0    delhi
# 2  charlie   19   90.0        75.0   mumbai
# 3    david   22   90.0        88.0    kochi
# 4     emma   20   65.0        88.0  chennai

# %%
df=pd.read_csv("/content/nigeria_messy_sales_dataset.csv")
df
# Out:
#           Customer Name    State     Product  Units Sold  Unit Price  \
# 0                   NaN   rivers    KEYBOARD         NaN         NaN
# 1          Allison Hill    Lagos  Headphones         NaN   267992.94
# 2           Noah Rhodes  Anambra    Keyboard         NaN    42364.41
# 3       Angie Henderson    Delta    Keyboard         NaN   279444.94
# 4         Daniel Wagner    Delta      Tablet         NaN    95899.74
# ..                  ...      ...         ...         ...         ...
# 545    Zachary Mitchell    Ekiti     Monitor         6.0    23989.09
# 546                 NaN  Katsina      Tablet         NaN   223764.24
# 547  Katherine Martinez   Bauchi       Phone         NaN   104084.92
# 548          Jodi Roach    Niger     Charger         NaN    29756.89
# 549     Brandon Fleming      imo      Camera         NaN    70027.13
#
#      Total Sale   Sale Date Sales Channel  \
# 0           NaN  2025-04-27        Online
# 1           NaN  2024-03-15     Wholesale
# ...

# %%
#tasks
import pandas as pd
df = pd.read_csv("/content/nigeria_messy_sales_dataset.csv")
print(df)
#1
print(df.shape)
#2
print(df.head(7))
print(df.tail(5))
#3
print(df["Product"],["Units sold"],["Units price"],["total sale"])
#4
print(df[df["Units Sold"]>50])
#5
print(df[df["Unit Price"]>100000])
#6
print(df[df["Sales Channel"]=="online"])
#7
print(df["State"].unique())
print(df["State"].nunique)
#8
print(df["Sales Channel"].value_counts())
#9
print(df.isnull().sum())
#10
print(df.dropna())
# Out:
#           Customer Name    State     Product  Units Sold  Unit Price  \
# 0                   NaN   rivers    KEYBOARD         NaN         NaN
# 1          Allison Hill    Lagos  Headphones         NaN   267992.94
# 2           Noah Rhodes  Anambra    Keyboard         NaN    42364.41
# 3       Angie Henderson    Delta    Keyboard         NaN   279444.94
# 4         Daniel Wagner    Delta      Tablet         NaN    95899.74
# ..                  ...      ...         ...         ...         ...
# 545    Zachary Mitchell    Ekiti     Monitor         6.0    23989.09
# 546                 NaN  Katsina      Tablet         NaN   223764.24
# 547  Katherine Martinez   Bauchi       Phone         NaN   104084.92
# 548          Jodi Roach    Niger     Charger         NaN    29756.89
# 549     Brandon Fleming      imo      Camera         NaN    70027.13
#
#      Total Sale   Sale Date Sales Channel  \
# 0           NaN  2025-04-27        Online
# 1           NaN  2024-03-15     Wholesale
# ...
